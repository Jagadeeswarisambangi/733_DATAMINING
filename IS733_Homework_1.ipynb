# %%
import pandas as pd

# Assuming you have a CSV file named "Baltimore911.csv" containing your dataset
# Replace "Baltimore911.csv" with the actual file path if it's located elsewhere
file_path = "Baltimore911.csv"

# Read the dataset into a pandas DataFrame
baltimore911_df = pd.read_csv("C:/Users/jagad/Downloads/Baltimore911.csv")

# Get the total number of rows/instances in the dataset
total_rows = len(baltimore911_df)

# Print the total number of rows
print("Total number of rows/instances in Baltimore911 dataset:", total_rows)
# Out:
# Total number of rows/instances in Baltimore911 dataset: 292761
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\2354286749.py:8: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   baltimore911_df = pd.read_csv("C:/Users/jagad/Downloads/Baltimore911.csv")

# %%
import pandas as pd

# Specify the data type for column 7 as a string
dtype_options = {"ColumnName7": str}

# Replace "Baltimore911.csv" with the actual file path if it's located elsewhere
file_path = "C:/Users/jagad/Downloads/Baltimore911.csv"

# Read the dataset into a pandas DataFrame, specifying the data types
Baltimore911_df = pd.read_csv(file_path, dtype=dtype_options)

# Get the total number of rows/instances in the dataset
total_rows = len(Baltimore911_df)

# Print the total number of rows
print("Total number of rows/instances in Baltimore911 dataset:", total_rows)
# Out:
# Total number of rows/instances in Baltimore911 dataset: 292761
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\1290712560.py:10: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   Baltimore911_df = pd.read_csv(file_path, dtype=dtype_options)

# %%
import pandas as pd

# Specify the data type for column 7 as a string
dtype_options = {"ColumnName7": str}

# Replace "Baltimore911.csv" with the actual file path if it's located elsewhere
file_path = "C:/Users/jagad/Downloads/Baltimore911.csv"

# Read the dataset into a pandas DataFrame, specifying the data types and low_memory=False
baltimore911_df = pd.read_csv(file_path, dtype=dtype_options, low_memory=False)

# Get the total number of rows/instances in the dataset
total_rows = len(baltimore911_df)

# Print the total number of rows
print("Total number of rows/instances in Baltimore911 dataset:", total_rows)
# Out:
# Total number of rows/instances in Baltimore911 dataset: 292761

# %%
import pandas as pd

# Replace "Baltimore911.csv" with the actual file path if it's located elsewhere
file_path = "C:/Users/jagad/Downloads/Baltimore911.csv"

# Read the dataset into a pandas DataFrame
baltimore911_df = pd.read_csv(file_path)

# Get the total number of columns (features) in the dataset
total_columns = len(baltimore911_df.columns)

# Print the total number of columns
print("Total number of call features/columns in Baltimore911 dataset:", total_columns)
# Out:
# Total number of call features/columns in Baltimore911 dataset: 16
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\3274341870.py:7: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   baltimore911_df = pd.read_csv(file_path)

# %%
import pandas as pd

# Specify the data type for column 7 as a string
dtype_options = {"ColumnName7": str}

# Replace "Baltimore911.csv" with the actual file path if it's located elsewhere
file_path = "C:/Users/jagad/Downloads/Baltimore911.csv"

# Read the dataset into a pandas DataFrame, specifying the data types and low_memory=False
baltimore911_df = pd.read_csv(file_path, dtype=dtype_options, low_memory=False)

# Get the total number of columns (features) in the dataset
total_columns = len(baltimore911_df.columns)

# Print the total number of columns
print("Total number of call features/columns in Baltimore911 dataset:", total_columns)
# Out:
# Total number of call features/columns in Baltimore911 dataset: 16

# %%
import pandas as pd

# Replace "Baltimore911.csv" with the actual file path if it's located elsewhere
file_path = "C:/Users/jagad/Downloads/Baltimore911.csv"

# Read the dataset into a pandas DataFrame
baltimore911_df = pd.read_csv(file_path)

# Create dictionaries to categorize columns
numeric_columns = {}
symbolic_columns = {}
temporal_columns = {}
spatial_columns = {}

# Define the threshold for considering a column as numeric
numeric_threshold = 10

# Loop through columns and categorize them
for column in baltimore911_df.columns:
    column_data = baltimore911_df[column]
    unique_values = column_data.nunique()
    data_type = str(column_data.dtype)
    
    if unique_values <= numeric_threshold:
        symbolic_columns[column] = data_type + " (Discrete)"
    else:
        try:
            pd.to_datetime(column_data)  # Check if it's a date/time column
            temporal_columns[column] = "Temporal"
        except ValueError:
            symbolic_columns[column] = data_type + " (Discrete)"

# Print the categorization of columns
print("Column Categorization:")
print("=======================")
print("Numeric/Continuous Columns:")
for column, data_type in numeric_columns.items():
    print(f"{column}: {data_type}")
print("\nSymbolic/Discrete Columns:")
for column, data_type in symbolic_columns.items():
    print(f"{column}: {data_type}")
print("\nTemporal Columns:")
for column, data_type in temporal_columns.keys():
    print(column, ": Temporal")

# Note: Spatial data detection is not included in this code and would require domain-specific knowledge.
# Out:
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\2333441899.py:7: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   baltimore911_df = pd.read_csv(file_path)
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\2333441899.py:28: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(column_data)  # Check if it's a date/time column
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\2333441899.py:28: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(column_data)  # Check if it's a date/time column
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\2333441899.py:28: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(column_data)  # Check if it's a date/time column
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\2333441899.py:28: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(column_data)  # Check if it's a date/time column
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\2333441899.py:28: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(column_data)  # Check if it's a date/time column
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\2333441899.py:28: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(column_data)  # Check if it's a date/time column
# Column Categorization:
# =======================
# Numeric/Continuous Columns:
#
# Symbolic/Discrete Columns:
# CrimeCode: object (Discrete)
# Location: object (Discrete)
# Description: object (Discrete)
# Inside/Outside: object (Discrete)
# Weapon: object (Discrete)
# Post: object (Discrete)
# District: object (Discrete)
# Neighborhood: object (Discrete)
# Location 1: float64 (Discrete)
# Premise: object (Discrete)
# vri_name1: object (Discrete)
# Total Incidents: int64 (Discrete)
#
# Temporal Columns:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 43
#      41     print(f"{column}: {data_type}")
#      42 print("\nTemporal Columns:")
# ---> 43 for column, data_type in temporal_columns.keys():
#      44     print(column, ": Temporal")
#
# ValueError: too many values to unpack (expected 2)

# %%
import pandas as pd

# Replace "Baltimore911.csv" with the actual file path if it's located elsewhere
file_path = "C:/Users/jagad/Downloads/Baltimore911.csv"

# Read the dataset into a pandas DataFrame
baltimore911_df = pd.read_csv(file_path)

# Create dictionaries to categorize columns
numeric_columns = {}
symbolic_columns = {}
temporal_columns = {}
spatial_columns = {}

# Define the threshold for considering a column as numeric
numeric_threshold = 10

# Loop through columns and categorize them
for column in baltimore911_df.columns:
    column_data = baltimore911_df[column]
    unique_values = column_data.nunique()
    data_type = str(column_data.dtype)
    
    if unique_values <= numeric_threshold:
        symbolic_columns[column] = data_type + " (Discrete)"
    else:
        try:
            pd.to_datetime(column_data, errors='raise')  # Check if it's a date/time column
            temporal_columns[column] = "Temporal"
        except (ValueError, TypeError):
            symbolic_columns[column] = data_type + " (Discrete)"

# Print the categorization of columns
print("Column Categorization:")
print("=======================")
print("Numeric/Continuous Columns:")
for column, data_type in numeric_columns.items():
    print(f"{column}: {data_type}")
print("\nSymbolic/Discrete Columns:")
for column, data_type in symbolic_columns.items():
    print(f"{column}: {data_type}")
print("\nTemporal Columns:")
for column, data_type in temporal_columns.keys():
    print(column, ": Temporal")

# Note: Spatial data detection is not included in this code and would require domain-specific knowledge.
# Out:
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\34743775.py:7: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   baltimore911_df = pd.read_csv(file_path)
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\34743775.py:28: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(column_data, errors='raise')  # Check if it's a date/time column
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\34743775.py:28: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(column_data, errors='raise')  # Check if it's a date/time column
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\34743775.py:28: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(column_data, errors='raise')  # Check if it's a date/time column
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\34743775.py:28: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(column_data, errors='raise')  # Check if it's a date/time column
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\34743775.py:28: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(column_data, errors='raise')  # Check if it's a date/time column
# Column Categorization:
# =======================
# Numeric/Continuous Columns:
#
# Symbolic/Discrete Columns:
# CrimeCode: object (Discrete)
# Location: object (Discrete)
# Description: object (Discrete)
# Inside/Outside: object (Discrete)
# Weapon: object (Discrete)
# Post: object (Discrete)
# District: object (Discrete)
# Neighborhood: object (Discrete)
# Location 1: float64 (Discrete)
# Premise: object (Discrete)
# vri_name1: object (Discrete)
# Total Incidents: int64 (Discrete)
#
# Temporal Columns:
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\34743775.py:28: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(column_data, errors='raise')  # Check if it's a date/time column
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 43
#      41     print(f"{column}: {data_type}")
#      42 print("\nTemporal Columns:")
# ---> 43 for column, data_type in temporal_columns.keys():
#      44     print(column, ": Temporal")
#
# ValueError: too many values to unpack (expected 2)

# %%
import pandas as pd

# Replace "Baltimore911.csv" with the actual file path if it's located elsewhere
file_path = "C:/Users/jagad/Downloads/Baltimore911.csv"

# Read the dataset into a pandas DataFrame
baltimore911_df = pd.read_csv(file_path)

# Create dictionaries to categorize columns
numeric_columns = {}
symbolic_columns = {}
temporal_columns = {}
spatial_columns = {}

# Define the threshold for considering a column as numeric
numeric_threshold = 10

# Loop through columns and categorize them
for column in baltimore911_df.columns:
    column_data = baltimore911_df[column]
    unique_values = column_data.nunique()
    data_type = str(column_data.dtype)
    
    if unique_values <= numeric_threshold:
        symbolic_columns[column] = data_type + " (Discrete)"
    else:
        try:
            pd.to_datetime(column_data, errors='raise')  # Check if it's a date/time column
            temporal_columns[column] = "Temporal"
        except (ValueError, TypeError):
            symbolic_columns[column] = data_type + " (Discrete)"

# Print the categorization of columns
print("Column Categorization:")
print("=======================")
print("Numeric/Continuous Columns:")
for column, data_type in numeric_columns.items():
    print(f"{column}: {data_type}")
print("\nSymbolic/Discrete Columns:")
for column, data_type in symbolic_columns.items():
    print(f"{column}: {data_type}")
print("\nTemporal Columns:")
for column in temporal_columns.keys():
    print(column, ": Temporal")

# Note: Spatial data detection is not included in this code and would require domain-specific knowledge.
# Out:
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\3353328734.py:7: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   baltimore911_df = pd.read_csv(file_path)
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\3353328734.py:28: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(column_data, errors='raise')  # Check if it's a date/time column
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\3353328734.py:28: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(column_data, errors='raise')  # Check if it's a date/time column
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\3353328734.py:28: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(column_data, errors='raise')  # Check if it's a date/time column
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\3353328734.py:28: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(column_data, errors='raise')  # Check if it's a date/time column
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\3353328734.py:28: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(column_data, errors='raise')  # Check if it's a date/time column
# Column Categorization:
# =======================
# Numeric/Continuous Columns:
#
# Symbolic/Discrete Columns:
# CrimeCode: object (Discrete)
# Location: object (Discrete)
# Description: object (Discrete)
# Inside/Outside: object (Discrete)
# Weapon: object (Discrete)
# Post: object (Discrete)
# District: object (Discrete)
# Neighborhood: object (Discrete)
# Location 1: float64 (Discrete)
# Premise: object (Discrete)
# vri_name1: object (Discrete)
# Total Incidents: int64 (Discrete)
#
# Temporal Columns:
# CrimeDate : Temporal
# CrimeTime : Temporal
# Longitude : Temporal
# Latitude : Temporal
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\3353328734.py:28: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(column_data, errors='raise')  # Check if it's a date/time column

# %%
import pandas as pd

# Replace "Baltimore911.csv" with the actual file path if it's located elsewhere
file_path = "C:/Users/jagad/Downloads/Baltimore911.csv"

# Read the dataset into a pandas DataFrame, specifying low_memory=False
baltimore911_df = pd.read_csv(file_path, low_memory=False)

# Create dictionaries to categorize columns
numeric_columns = {}
symbolic_columns = {}
temporal_columns = {}
spatial_columns = {}

# Define the threshold for considering a column as numeric
numeric_threshold = 10

# Loop through columns and categorize them
for column in baltimore911_df.columns:
    column_data = baltimore911_df[column]
    unique_values = column_data.nunique()
    data_type = str(column_data.dtype)
    
    if unique_values <= numeric_threshold:
        symbolic_columns[column] = data_type + " (Discrete)"
    else:
        try:
            pd.to_datetime(column_data, errors='raise')  # Check if it's a date/time column
            temporal_columns[column] = "Temporal"
        except (ValueError, TypeError):
            symbolic_columns[column] = data_type + " (Discrete)"

# Print the categorization of columns
print("Column Categorization:")
print("=======================")
print("Numeric/Continuous Columns:")
for column, data_type in numeric_columns.items():
    print(f"{column}: {data_type}")
print("\nSymbolic/Discrete Columns:")
for column, data_type in symbolic_columns.items():
    print(f"{column}: {data_type}")
print("\nTemporal Columns:")
for column in temporal_columns.keys():
    print(column, ": Temporal")

# Note: Spatial data detection is not included in this code and would require domain-specific knowledge.
# Out:
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\973879138.py:28: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(column_data, errors='raise')  # Check if it's a date/time column
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\973879138.py:28: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(column_data, errors='raise')  # Check if it's a date/time column
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\973879138.py:28: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(column_data, errors='raise')  # Check if it's a date/time column
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\973879138.py:28: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(column_data, errors='raise')  # Check if it's a date/time column
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\973879138.py:28: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(column_data, errors='raise')  # Check if it's a date/time column
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\973879138.py:28: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(column_data, errors='raise')  # Check if it's a date/time column
# Column Categorization:
# =======================
# Numeric/Continuous Columns:
#
# Symbolic/Discrete Columns:
# CrimeCode: object (Discrete)
# Location: object (Discrete)
# Description: object (Discrete)
# Inside/Outside: object (Discrete)
# Weapon: object (Discrete)
# Post: object (Discrete)
# District: object (Discrete)
# Neighborhood: object (Discrete)
# Location 1: float64 (Discrete)
# Premise: object (Discrete)
# vri_name1: object (Discrete)
# Total Incidents: int64 (Discrete)
#
# Temporal Columns:
# CrimeDate : Temporal
# CrimeTime : Temporal
# Longitude : Temporal
# Latitude : Temporal
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\973879138.py:28: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(column_data, errors='raise')  # Check if it's a date/time column

# %%
import pandas as pd

# Replace "Baltimore911.csv" with the actual file path if it's located elsewhere
file_path = "C:/Users/jagad/Downloads/Baltimore911.csv"

# Read the dataset into a pandas DataFrame, specifying low_memory=False
baltimore911_df = pd.read_csv(file_path, low_memory=False)

# Create a list to store the names of discrete attributes
discrete_attributes = []

# Create a dictionary to store the results
discrete_results = {}

# Define the threshold for considering a column as discrete (you can adjust this as needed)
numeric_threshold = 10

# Loop through columns and categorize them
for column in baltimore911_df.columns:
    column_data = baltimore911_df[column]
    unique_values = column_data.nunique()
    data_type = str(column_data.dtype)
    
    if unique_values <= numeric_threshold:
        discrete_attributes.append(column)
        value_counts = column_data.value_counts()
        top_values = value_counts.head(3)
        discrete_results[column] = {
            "Total Unique Values": unique_values,
            "Top 3 Values with Counts": top_values.to_dict(),
        }

# Print results for discrete attributes
print("Discrete Attribute Information:")
print("==============================")
for attribute in discrete_attributes:
    print(f"Attribute: {attribute}")
    results = discrete_results[attribute]
    print(f"Total Unique Values: {results['Total Unique Values']}")
    print("Top 3 Values with Counts:")
    for value, count in results["Top 3 Values with Counts"].items():
        print(f"{value}: {count}")
    print("\n")
# Out:
# Discrete Attribute Information:
# ==============================
# Attribute: Inside/Outside
# Total Unique Values: 4
# Top 3 Values with Counts:
# O: 128776
# I: 124454
# Outside: 5113
#
#
# Attribute: Weapon
# Total Unique Values: 5
# Top 3 Values with Counts:
# FIREARM: 29036
# OTHER: 17313
# KNIFE: 10023
#
#
# Attribute: District
# Total Unique Values: 10
# Top 3 Values with Counts:
# NORTHEAST: 44207
# SOUTHEAST: 41816
# CENTRAL: 33508
#
#
# Attribute: Location 1
# Total Unique Values: 0
# Top 3 Values with Counts:
#
#
# Attribute: vri_name1
# Total Unique Values: 8
# Top 3 Values with Counts:
# Tri-District: 6607
# Western: 5825
# Central: 5420
#
#
# Attribute: Total Incidents
# Total Unique Values: 1
# Top 3 Values with Counts:
# 1: 292761

# %%
import pandas as pd

# Replace "Baltimore911.csv" with the actual file path if it's located elsewhere
file_path = "C:/Users/jagad/Downloads/Baltimore911.csv"

# Read the dataset into a pandas DataFrame
baltimore911_df = pd.read_csv(file_path)

# Calculate the percentage of missing values for each row
missing_percentage_per_row = baltimore911_df.isnull().mean(axis=1) * 100

# Calculate the overall percentage of missing values across all rows
overall_missing_percentage = missing_percentage_per_row.mean()

# Print the overall percentage of missing values
print(f"Overall Percentage of Missing Values: {overall_missing_percentage:.2f}%")
# Out:
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\2782919229.py:7: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   baltimore911_df = pd.read_csv(file_path)
# Overall Percentage of Missing Values: 18.52%

# %%
import pandas as pd

# Replace "Baltimore911.csv" with the actual file path if it's located elsewhere
file_path = "C:/Users/jagad/Downloads/Baltimore911.csv"

# Read the dataset into a pandas DataFrame, specifying low_memory=False
baltimore911_df = pd.read_csv(file_path, low_memory=False)

# Calculate the percentage of missing values for each row
missing_percentage_per_row = baltimore911_df.isnull().mean(axis=1) * 100

# Calculate the overall percentage of missing values across all rows
overall_missing_percentage = missing_percentage_per_row.mean()

# Print the overall percentage of missing values
print(f"Overall Percentage of Missing Values: {overall_missing_percentage:.2f}%")
# Out:
# Overall Percentage of Missing Values: 18.52%

# %%
import pandas as pd

# Replace "Baltimore911.csv" with the actual file path if it's located elsewhere
file_path = "C:/Users/jagad/Downloads/Baltimore911.csv"

# Read the dataset into a pandas DataFrame
baltimore911_df = pd.read_csv(file_path, low_memory=False)

# Specify the columns you want to include in the dataset profile
selected_columns = [
    "CrimeDate", "CrimeTime", "CrimeCode", "Location", "Description", 
    "Inside/Outside", "Weapon", "Post", "District", "Neighborhood", 
    "Longitude", "Latitude", "Location 1", "Premise", "vri_name1", "Total Incidents"
]

# Create a summary DataFrame for the selected columns
profile_df = baltimore911_df[selected_columns]

# Generate summary statistics for numeric columns (Longitude, Latitude)
numeric_summary = profile_df[["Longitude", "Latitude"]].describe()

# Calculate the number of unique values for each non-numeric column
unique_counts = profile_df.select_dtypes(exclude=['number']).nunique().rename("Unique Values")

# Combine the summary statistics and unique value counts
profile_summary = pd.concat([numeric_summary, unique_counts])

# Print the dataset profile summary
print(profile_summary)
# Out:
#                     Longitude       Latitude        0
# count           291126.000000  291126.000000      NaN
# mean               -76.617452      39.306746      NaN
# std                  0.043734       0.029658      NaN
# min                -81.529189      37.577262      NaN
# 25%                -76.649094      39.288186      NaN
# 50%                -76.613977      39.302672      NaN
# 75%                -76.587080      39.326965      NaN
# max                -76.383228      39.661332      NaN
# CrimeDate                 NaN            NaN   2300.0
# CrimeTime                 NaN            NaN   1475.0
# CrimeCode                 NaN            NaN     81.0
# Location                  NaN            NaN  27064.0
# Description               NaN            NaN     14.0
# Inside/Outside            NaN            NaN      4.0
# Weapon                    NaN            NaN      5.0
# Post                      NaN            NaN    133.0
# District                  NaN            NaN     10.0
# Neighborhood              NaN            NaN    278.0
# Premise                   NaN            NaN    125.0
# vri_name1                 NaN            NaN      8.0

# %%
import pandas as pd

# Replace "Baltimore911.csv" with the actual file path if it's located elsewhere
file_path = "C:/Users/jagad/Downloads/Baltimore911.csv"

# Read the dataset into a pandas DataFrame
baltimore911_df = pd.read_csv(file_path, low_memory=False)

# Specify the columns you want to clean
selected_columns = [
    "CrimeDate", "CrimeTime", "CrimeCode", "Location", "Description", 
    "Inside/Outside", "Weapon", "Post", "District", "Neighborhood", 
    "Longitude", "Latitude", "Location 1", "Premise", "vri_name1", "Total Incidents"
]

# Step 1: Handling Missing Values
baltimore911_df[selected_columns] = baltimore911_df[selected_columns].fillna("")

# Step 2: Removing Duplicates
baltimore911_df.drop_duplicates(subset=selected_columns, inplace=True)

# Step 3: Data Type Conversion (if needed)
# Example: Convert "CrimeDate" to datetime
baltimore911_df["CrimeDate"] = pd.to_datetime(baltimore911_df["CrimeDate"], errors="coerce")

# Step 4: Data Validation (address inconsistencies if found)

# Step 5: Data Quality Checks (perform final data quality checks)

# After completing the cleaning steps, you may save the cleaned dataset to a new CSV file
# baltimore911_df.to_csv("cleaned_Baltimore911.csv", index=False)

# %%
missing_values = baltimore911_df.isnull().sum()
if missing_values.sum() == 0:
    print("No missing values remaining in the dataset.")
# Out:
# No missing values remaining in the dataset.

# %%
duplicates = baltimore911_df.duplicated().sum()
if duplicates == 0:
    print("No duplicate rows remaining in the dataset.")
# Out:
# No duplicate rows remaining in the dataset.

# %%
if pd.api.types.is_datetime64_any_dtype(baltimore911_df["CrimeDate"]):
    print("Date column (CrimeDate) is in datetime format.")
# Out:
# Date column (CrimeDate) is in datetime format.

# %%
print(baltimore911_df.head())
# Out:
#    CrimeDate CrimeTime CrimeCode            Location          Description  \
# 0 2020-02-08   2:18:00        5D  1700 CLIFTVIEW AVE             BURGLARY
# 1 2020-02-08   6:00:00        6G   700 N STREEPER ST              LARCENY
# 2 2020-02-08   9:50:00       3JF     1400 N BROADWAY  ROBBERY - RESIDENCE
# 4 2020-02-08  17:30:00        5A    1600 E OLIVER ST             BURGLARY
# 5 2020-02-08  19:00:00        5A    1400 AISQUITH ST             BURGLARY
#
#   Inside/Outside   Weapon Post District     Neighborhood  Longitude  \
# 0              I           312  EASTERN      DARLEY PARK  -76.59387
# 1              I           333  EASTERN  MADISON EASTEND -76.577425
# 2              I  FIREARM  314  EASTERN           OLIVER -76.594992
# 4              I           314  EASTERN           OLIVER -76.595946
# 5              I                EASTERN
#
#     Latitude Location 1             Premise  vri_name1  Total Incidents
# 0  39.315341             GROCERY/CONFECTION  Eastern 1                1
# 1  39.299094              ROW/TOWNHOUSE-OCC                           1
# 2  39.306941              ROW/TOWNHOUSE-OCC                           1
# 4   39.30735              ROW/TOWNHOUSE-OCC  Eastern 1                1
# 5                         ROW/TOWNHOUSE-OCC                           1

# %%
print(baltimore911_df.describe())
# Out:
#                            CrimeDate  Total Incidents
# count                         281319         281319.0
# mean   2017-01-23 10:06:51.163128320              1.0
# min              1963-10-30 00:00:00              1.0
# 25%              2015-08-05 00:00:00              1.0
# 50%              2017-01-29 00:00:00              1.0
# 75%              2018-07-21 00:00:00              1.0
# max              2020-02-08 00:00:00              1.0
# std                              NaN              0.0

# %%
missing_values = baltimore911_df.isnull().sum()
print("Missing Values:")
print(missing_values)
# Out:
# Missing Values:
# CrimeDate          0
# CrimeTime          0
# CrimeCode          0
# Location           0
# Description        0
# Inside/Outside     0
# Weapon             0
# Post               0
# District           0
# Neighborhood       0
# Longitude          0
# Latitude           0
# Location 1         0
# Premise            0
# vri_name1          0
# Total Incidents    0
# dtype: int64

# %%
duplicate_rows = baltimore911_df[selected_columns].duplicated().sum()
print(f"Number of Duplicate Rows: {duplicate_rows}")
# Out:
# Number of Duplicate Rows: 0

# %%
data_types = baltimore911_df[selected_columns].dtypes
print("Data Types:")
print(data_types)
# Out:
# Data Types:
# CrimeDate          datetime64[ns]
# CrimeTime                  object
# CrimeCode                  object
# Location                   object
# Description                object
# Inside/Outside             object
# Weapon                     object
# Post                       object
# District                   object
# Neighborhood               object
# Longitude                  object
# Latitude                   object
# Location 1                 object
# Premise                    object
# vri_name1                  object
# Total Incidents             int64
# dtype: object

# %%
sample_data = baltimore911_df[selected_columns].sample(5)  # Adjust the sample size as needed
print("Sample Data:")
print(sample_data)
# Out:
# Sample Data:
#         CrimeDate CrimeTime CrimeCode             Location       Description  \
# 226960 2015-06-17   2:00:00        4C       1600 JOPLIN ST      AGG. ASSAULT
# 218127 2015-08-16   0:00:00        4E         5700 PULASKI    COMMON ASSAULT
# 39318  2019-04-02  11:41:00        4E  1800 W BALTIMORE ST    COMMON ASSAULT
# 209366 2015-10-16  15:50:00       3AF       3300 ESTHER PL  ROBBERY - STREET
# 4243   2019-12-27  11:00:00        6J    2000 MARYLAND AVE           LARCENY
#
#        Inside/Outside   Weapon Post   District          Neighborhood  \
# 226960              O    OTHER  234  SOUTHEAST  MEDFORD/BROENING MAN
# 218127              O           433  NORTHEAST     ARMISTEAD GARDENS
# 39318               O           711    WESTERN       FRANKLIN SQUARE
# 209366              O  FIREARM  222  SOUTHEAST     BALTIMORE-LINWOOD
# 4243                            514   NORTHERN         CHARLES NORTH
#
#         Longitude   Latitude Location 1 Premise     vri_name1  Total Incidents
# 226960 -76.537097  39.274312             STREET                              1
# 218127 -76.550011  39.301372             STREET                              1
# 39318  -76.645292  39.288319              ALLEY  Tri-District                1
# 209366 -76.570424  39.294291              ALLEY                              1
# 4243   -76.618038  39.312224                                                 1

# %%
summary_stats = baltimore911_df[selected_columns].describe()
print("Summary Statistics:")
print(summary_stats)
# Out:
# Summary Statistics:
#                            CrimeDate  Total Incidents
# count                         281319         281319.0
# mean   2017-01-23 10:06:51.163128320              1.0
# min              1963-10-30 00:00:00              1.0
# 25%              2015-08-05 00:00:00              1.0
# 50%              2017-01-29 00:00:00              1.0
# 75%              2018-07-21 00:00:00              1.0
# max              2020-02-08 00:00:00              1.0
# std                              NaN              0.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Replace "Baltimore911.csv" with the actual file path if it's located elsewhere
file_path = "C:/Users/jagad/Downloads/Baltimore911.csv"

# Read the dataset into a pandas DataFrame
baltimore911_df = pd.read_csv(file_path, low_memory=False)

# Ensure the "CrimeDate" column is in datetime format
baltimore911_df['CrimeDate'] = pd.to_datetime(baltimore911_df['CrimeDate'], errors='coerce')

# Create a new DataFrame with date-related information
date_info = baltimore911_df[['CrimeDate', 'Total Incidents']].copy()
date_info['Year'] = date_info['CrimeDate'].dt.year
date_info['Month'] = date_info['CrimeDate'].dt.month
date_info['DayOfWeek'] = date_info['CrimeDate'].dt.dayofweek  # Monday is 0, Sunday is 6

# Group data by year, month, and day of the week, and calculate total incidents
yearly_data = date_info.groupby('Year')['Total Incidents'].sum()
monthly_data = date_info.groupby('Month')['Total Incidents'].sum()
day_of_week_data = date_info.groupby('DayOfWeek')['Total Incidents'].sum()

# Create subplots for year-to-year, monthly, and day-of-week plots
fig, axes = plt.subplots(3, 1, figsize=(12, 12))

# Year-to-Year Plot
sns.lineplot(x=yearly_data.index, y=yearly_data.values, ax=axes[0])
axes[0].set_title('Year-to-Year Crime Incidence')
axes[0].set_xlabel('Year')
axes[0].set_ylabel('Total Incidents')

# Monthly Plot
sns.barplot(x=monthly_data.index, y=monthly_data.values, ax=axes[1])
axes[1].set_title('Monthly Crime Incidence')
axes[1].set_xlabel('Month')
axes[1].set_ylabel('Total Incidents')
axes[1].set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])

# Day-of-Week Plot
day_names = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
sns.barplot(x=day_of_week_data.index, y=day_of_week_data.values, ax=axes[2])
axes[2].set_title('Day-of-Week Crime Incidence')
axes[2].set_xlabel('Day of the Week')
axes[2].set_ylabel('Total Incidents')
axes[2].set_xticklabels(day_names)

# Adjust layout and display the plots
plt.tight_layout()
plt.show()
# Out:
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Replace "Baltimore911.csv" with the actual file path if it's located elsewhere
file_path = "C:/Users/jagad/Downloads/Baltimore911.csv"

# Read the dataset into a pandas DataFrame
baltimore911_df = pd.read_csv(file_path, low_memory=False)

# Group data by crime type and calculate the count of each crime type
crime_type_counts = baltimore911_df['Description'].value_counts()

# Filter out low-frequency crime types for better visualization (adjust threshold as needed)
min_count_threshold = 500
filtered_crime_types = crime_type_counts[crime_type_counts >= min_count_threshold]

# Create a bar plot to visualize the distribution of crime types
plt.figure(figsize=(12, 6))
sns.barplot(x=filtered_crime_types.values, y=filtered_crime_types.index, palette='viridis')

# Customize plot labels and title
plt.xlabel('Count of Incidents')
plt.ylabel('Crime Type')
plt.title('Distribution of Crime Types (All Locations and Time Periods)')

# Show the plot
plt.show()
# Out:
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Replace "Baltimore911.csv" with the actual file path if it's located elsewhere
file_path = "C:/Users/jagad/Downloads/Baltimore911.csv"

# Read the dataset into a pandas DataFrame
baltimore911_df = pd.read_csv(file_path, low_memory=False)

# Ensure the "CrimeDate" column is in datetime format
baltimore911_df['CrimeDate'] = pd.to_datetime(baltimore911_df['CrimeDate'], errors='coerce')

# Extract year, month, and day of the week from the "CrimeDate" column
baltimore911_df['Year'] = baltimore911_df['CrimeDate'].dt.year
baltimore911_df['Month'] = baltimore911_df['CrimeDate'].dt.month
baltimore911_df['DayOfWeek'] = baltimore911_df['CrimeDate'].dt.dayofweek  # Monday is 0, Sunday is 6

# Create subplots for year-to-year, month-to-month, and day-of-week plots
fig, axes = plt.subplots(3, 1, figsize=(12, 12))

# Year-to-Year Crime Type Distribution
sns.countplot(x='Year', hue='Description', data=baltimore911_df, ax=axes[0])
axes[0].set_title('Year-to-Year Crime Type Distribution')
axes[0].set_xlabel('Year')
axes[0].set_ylabel('Count of Incidents')
axes[0].legend(title='Crime Type', bbox_to_anchor=(1.05, 1), loc='upper left')

# Monthly Crime Type Distribution
sns.countplot(x='Month', hue='Description', data=baltimore911_df, ax=axes[1])
axes[1].set_title('Monthly Crime Type Distribution')
axes[1].set_xlabel('Month')
axes[1].set_ylabel('Count of Incidents')
axes[1].legend(title='Crime Type', bbox_to_anchor=(1.05, 1), loc='upper left')
axes[1].set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])

# Day-of-Week Crime Type Distribution
sns.countplot(x='DayOfWeek', hue='Description', data=baltimore911_df, ax=axes[2])
axes[2].set_title('Day-of-Week Crime Type Distribution')
axes[2].set_xlabel('Day of the Week')
axes[2].set_ylabel('Count of Incidents')
axes[2].legend(title='Crime Type', bbox_to_anchor=(1.05, 1), loc='upper left')
axes[2].set_xticklabels(['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'])

# Adjust layout and display the plots
plt.tight_layout()
plt.show()
# Out:
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Replace "Baltimore911.csv" with the actual file path if it's located elsewhere
file_path = "C:/Users/jagad/Downloads/Baltimore911.csv"

# Read the dataset into a pandas DataFrame
baltimore911_df = pd.read_csv(file_path, low_memory=False)

# Ensure the "CrimeDate" column is in datetime format
baltimore911_df['CrimeDate'] = pd.to_datetime(baltimore911_df['CrimeDate'], errors='coerce')

# Extract year, month, and day of the week from the "CrimeDate" column
baltimore911_df['Year'] = baltimore911_df['CrimeDate'].dt.year
baltimore911_df['Month'] = baltimore911_df['CrimeDate'].dt.month
baltimore911_df['DayOfWeek'] = baltimore911_df['CrimeDate'].dt.dayofweek  # Monday is 0, Sunday is 6

# Create subplots for year-to-year, month-to-month, and day-of-week plots
fig, axes = plt.subplots(3, 1, figsize=(12, 12))

# Year-to-Year Crime Type Distribution
sns.countplot(x='Year', hue='Description', data=baltimore911_df, ax=axes[0])
axes[0].set_title('Year-to-Year Crime Type Distribution')
axes[0].set_xlabel('Year')
axes[0].set_ylabel('Count of Incidents')
axes[0].legend(title='Crime Type', bbox_to_anchor=(1.05, 1), loc='upper left')
axes[0].tick_params(axis='x', rotation=90)  # Rotate x-axis labels vertically

# Monthly Crime Type Distribution
sns.countplot(x='Month', hue='Description', data=baltimore911_df, ax=axes[1])
axes[1].set_title('Monthly Crime Type Distribution')
axes[1].set_xlabel('Month')
axes[1].set_ylabel('Count of Incidents')
axes[1].legend(title='Crime Type', bbox_to_anchor=(1.05, 1), loc='upper left')
axes[1].set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])

# Day-of-Week Crime Type Distribution
sns.countplot(x='DayOfWeek', hue='Description', data=baltimore911_df, ax=axes[2])
axes[2].set_title('Day-of-Week Crime Type Distribution')
axes[2].set_xlabel('Day of the Week')
axes[2].set_ylabel('Count of Incidents')
axes[2].legend(title='Crime Type', bbox_to_anchor=(1.05, 1), loc='upper left')
axes[2].set_xticklabels(['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'])

# Adjust layout and display the plots
plt.tight_layout()
plt.show()
# Out:
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jagad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
import pandas as pd
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px

# Replace "Baltimore911.csv" with the actual file path if it's located elsewhere
file_path = "C:/Users/jagad/Downloads/Baltimore911.csv"

# Read the dataset into a pandas DataFrame
baltimore911_df = pd.read_csv(file_path, low_memory=False)

# Ensure the "CrimeDate" column is in datetime format
baltimore911_df['CrimeDate'] = pd.to_datetime(baltimore911_df['CrimeDate'], errors='coerce')

baltimore911_df.head(3)
# Out:
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\4131459233.py:3: UserWarning:
#
#
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#
# C:\Users\jagad\AppData\Local\Temp\ipykernel_11688\4131459233.py:4: UserWarning:
#
#
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#    CrimeDate CrimeTime CrimeCode            Location          Description  \
# 0 2020-02-08   2:18:00        5D  1700 CLIFTVIEW AVE             BURGLARY
# 1 2020-02-08   6:00:00        6G   700 N STREEPER ST              LARCENY
# 2 2020-02-08   9:50:00       3JF     1400 N BROADWAY  ROBBERY - RESIDENCE
#
#   Inside/Outside   Weapon Post District     Neighborhood  Longitude  \
# 0              I      NaN  312  EASTERN      DARLEY PARK -76.593870
# 1              I      NaN  333  EASTERN  MADISON EASTEND -76.577425
# 2              I  FIREARM  314  EASTERN           OLIVER -76.594992
#
#     Latitude  Location 1             Premise  vri_name1  Total Incidents
# 0  39.315341         NaN  GROCERY/CONFECTION  Eastern 1                1
# 1  39.299094         NaN   ROW/TOWNHOUSE-OCC        NaN                1
# 2  39.306941         NaN   ROW/TOWNHOUSE-OCC        NaN                1

# %%
# !pip install  skimpy
# Out:
# Requirement already satisfied: skimpy in c:\users\jagad\anaconda3\lib\site-packages (0.0.11)
# Requirement already satisfied: Pygments<3.0.0,>=2.10.0 in c:\users\jagad\anaconda3\lib\site-packages (from skimpy) (2.15.1)
# Requirement already satisfied: click<9.0.0,>=8.1.6 in c:\users\jagad\anaconda3\lib\site-packages (from skimpy) (8.1.7)
# Requirement already satisfied: ipykernel<7.0.0,>=6.7.0 in c:\users\jagad\anaconda3\lib\site-packages (from skimpy) (6.19.2)
# Requirement already satisfied: jupyter<2.0.0,>=1.0.0 in c:\users\jagad\anaconda3\lib\site-packages (from skimpy) (1.0.0)
# Requirement already satisfied: numpy<2.0.0,>=1.22.2 in c:\users\jagad\anaconda3\lib\site-packages (from skimpy) (1.24.3)
# Requirement already satisfied: pandas<3.0.0,>=2.0.3 in c:\users\jagad\anaconda3\lib\site-packages (from skimpy) (2.1.1)
# Requirement already satisfied: polars<0.20.0,>=0.19.0 in c:\users\jagad\anaconda3\lib\site-packages (from skimpy) (0.19.6)
# Requirement already satisfied: pyarrow<14.0.0,>=13.0.0 in c:\users\jagad\anaconda3\lib\site-packages (from skimpy) (13.0.0)
# Requirement already satisfied: rich<14.0,>=10.9 in c:\users\jagad\anaconda3\lib\site-packages (from skimpy) (13.6.0)
# Requirement already satisfied: typeguard==4.1.4 in c:\users\jagad\anaconda3\lib\site-packages (from skimpy) (4.1.4)
# Requirement already satisfied: typing-extensions>=4.7.0 in c:\users\jagad\anaconda3\lib\site-packages (from typeguard==4.1.4->skimpy) (4.7.1)
# Requirement already satisfied: colorama in c:\users\jagad\anaconda3\lib\site-packages (from click<9.0.0,>=8.1.6->skimpy) (0.4.6)
# Requirement already satisfied: comm>=0.1.1 in c:\users\jagad\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in c:\users\jagad\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\jagad\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (8.12.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\jagad\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\jagad\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\jagad\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (1.5.6)
# Requirement already satisfied: packaging in c:\users\jagad\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (23.0)
# Requirement already satisfied: psutil in c:\users\jagad\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (5.9.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\jagad\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\jagad\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (6.3.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\jagad\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (5.7.1)
# Requirement already satisfied: notebook in c:\users\jagad\anaconda3\lib\site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (6.5.4)
# Requirement already satisfied: qtconsole in c:\users\jagad\anaconda3\lib\site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (5.4.2)
# Requirement already satisfied: jupyter-console in c:\users\jagad\anaconda3\lib\site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\jagad\anaconda3\lib\site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (6.5.4)
# Requirement already satisfied: ipywidgets in c:\users\jagad\anaconda3\lib\site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (8.0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jagad\anaconda3\lib\site-packages (from pandas<3.0.0,>=2.0.3->skimpy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jagad\anaconda3\lib\site-packages (from pandas<3.0.0,>=2.0.3->skimpy) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\jagad\anaconda3\lib\site-packages (from pandas<3.0.0,>=2.0.3->skimpy) (2023.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\jagad\anaconda3\lib\site-packages (from rich<14.0,>=10.9->skimpy) (2.2.0)
# Requirement already satisfied: backcall in c:\users\jagad\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.0)
# Requirement already satisfied: decorator in c:\users\jagad\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\jagad\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\jagad\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\jagad\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (3.0.36)
# Requirement already satisfied: stack-data in c:\users\jagad\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.0)
# Requirement already satisfied: entrypoints in c:\users\jagad\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel<7.0.0,>=6.7.0->skimpy) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\jagad\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel<7.0.0,>=6.7.0->skimpy) (5.3.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\jagad\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<14.0,>=10.9->skimpy) (0.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\jagad\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.0.3->skimpy) (1.16.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\jagad\anaconda3\lib\site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\jagad\anaconda3\lib\site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (3.0.5)
# Requirement already satisfied: lxml in c:\users\jagad\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\jagad\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (4.12.2)
# Requirement already satisfied: bleach in c:\users\jagad\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\jagad\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\jagad\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (3.1.2)
# Requirement already satisfied: jupyterlab-pygments in c:\users\jagad\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jagad\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\jagad\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\jagad\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.5.13)
# Requirement already satisfied: nbformat>=5.1 in c:\users\jagad\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (5.7.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\jagad\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\jagad\anaconda3\lib\site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (1.2.1)
# Requirement already satisfied: argon2-cffi in c:\users\jagad\anaconda3\lib\site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (21.3.0)
# Requirement already satisfied: ipython-genutils in c:\users\jagad\anaconda3\lib\site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (0.2.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\jagad\anaconda3\lib\site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\jagad\anaconda3\lib\site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (0.17.1)
# Requirement already satisfied: prometheus-client in c:\users\jagad\anaconda3\lib\site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\jagad\anaconda3\lib\site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (0.5.5)
# Requirement already satisfied: qtpy>=2.0.1 in c:\users\jagad\anaconda3\lib\site-packages (from qtconsole->jupyter<2.0.0,>=1.0.0->skimpy) (2.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\jagad\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\jagad\anaconda3\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel<7.0.0,>=6.7.0->skimpy) (2.5.2)
# Requirement already satisfied: pywin32>=300 in c:\users\jagad\anaconda3\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel<7.0.0,>=6.7.0->skimpy) (305.1)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\jagad\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\jagad\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (0.2.2)
# Requirement already satisfied: fastjsonschema in c:\users\jagad\anaconda3\lib\site-packages (from nbformat>=5.1->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\jagad\anaconda3\lib\site-packages (from nbformat>=5.1->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (4.17.3)
# Requirement already satisfied: wcwidth in c:\users\jagad\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.5)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\jagad\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\jagad\anaconda3\lib\site-packages (from argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jagad\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (2.4)
# Requirement already satisfied: webencodings in c:\users\jagad\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.5.1)
# Requirement already satisfied: executing in c:\users\jagad\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\jagad\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\jagad\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.2)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\jagad\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\jagad\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.18.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\jagad\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (3.5.0)
# Requirement already satisfied: websocket-client in c:\users\jagad\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\jagad\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (1.15.1)
# Requirement already satisfied: idna>=2.8 in c:\users\jagad\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\jagad\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\jagad\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (2.21)

# %%
from skimpy import skim

skim(baltimore911_df)
# Out:
# C:\Users\jagad\anaconda3\Lib\site-packages\numpy\lib\histograms.py:883: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 292761 │ │ string      │ 11    │                                                          │
# │ │ Number of columns │ 19     │ │ int32       │ 4     │                                                          │
# │ └───────────────────┴────────┘ │ float64     │ 3     │                                                          │
# │                                │ datetime64  │ 1     │                                                          │
# │                                └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━━┓  │
# │ ┃ column_name         ┃ NA       ┃ NA %   ┃ mean  ┃ sd      ┃ p0    ┃ p25   ┃ p50   ┃ p75   ┃ p100  ┃ hist   ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━━┩  │
# │ │ Longitude           │     1635 │   0.56 │   -77 │   0.044 │   -82 │   -77 │   -77 │   -77 │   -76 │      ▇ │  │
# │ │ Latitude            │     1635 │   0.56 │    39 │    0.03 │    38 │    39 │    39 │    39 │    40 │     ▇▅ │  │
# │ │ Location 1          │   292761 │    100 │   nan │     nan │   nan │   nan │   nan │   nan │   nan │        │  │
# │ │ Total Incidents     │        0 │      0 │     1 │       0 │     1 │     1 │     1 │     1 │     1 │     ▇  │  │
# │ │ Year                │        0 │      0 │  2000 │     1.7 │  2000 │  2000 │  2000 │  2000 │  2000 │      ▇ │  │
# │ │ Month               │        0 │      0 │   6.6 │     3.4 │     1 │     4 │     7 │    10 │    12 │ ▇▇▇▇▇▇ │  │
# │ │ DayOfWeek           │        0 │      0 │     3 │       2 │     0 │     1 │     3 │     5 │     6 │ ▅▅▅▅▅▇ │  │
# │ └─────────────────────┴──────────┴────────┴───────┴─────────┴───────┴───────┴───────┴───────┴───────┴────────┘  │
# │                                                    datetime                                                     │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name            ┃ NA     ┃ NA %      ┃ first               ┃ last                ┃ frequency        ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩  │
# │ │ CrimeDate              │      0 │         0 │     1963-10-30      │     2020-02-08      │ None             │  │
# │ └────────────────────────┴────────┴───────────┴─────────────────────┴─────────────────────┴──────────────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name                 ┃ NA           ┃ NA %        ┃ words per row            ┃ total words          ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ CrimeTime                   │           26 │        0.01 │                        1 │               292735 │  │
# │ │ CrimeCode                   │            0 │           0 │                        1 │               292761 │  │
# │ │ Location                    │         1336 │        0.46 │                      3.4 │              1000942 │  │
# │ │ Description                 │            0 │           0 │                      1.8 │               539328 │  │
# │ │ Inside/Outside              │        33760 │       11.53 │                     0.88 │               259001 │  │
# │ │ Weapon                      │       231229 │       78.98 │                     0.21 │                61532 │  │
# │ │ Post                        │         2376 │        0.81 │                     0.99 │               290385 │  │
# │ │ District                    │            0 │           0 │                        1 │               292761 │  │
# │ │ Neighborhood                │        10504 │        3.59 │                      1.6 │               461736 │  │
# │ │ Premise                     │        34012 │       11.62 │                      1.3 │               367241 │  │
# │ │ vri_name1                   │       258177 │       88.19 │                     0.15 │                42654 │  │
# │ └─────────────────────────────┴──────────────┴─────────────┴──────────────────────────┴──────────────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯
